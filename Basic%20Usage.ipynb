# %%
from bokeh.io import push_notebook, show, output_notebook
from bokeh.layouts import row
from bokeh.plotting import figure
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="d549a1ab-e0a2-4bee-860c-97868685d4ec">Loading BokehJS ...</span>
#     </div>

# %%
opts = dict(plot_width=250, plot_height=250, min_border=0)

# %%
p1 = figure(**opts)
r1 = p1.circle([1,2,3], [4,5,6], size=20)

p2 = figure(**opts)
r2 = p2.circle([1,2,3], [4,5,6], size=20)

# get a handle to update the shown cell with
t = show(row(p1, p2), notebook_handle=True)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="9d5a2937-92fd-4f3d-a208-224f4eeb942a"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#9d5a2937-92fd-4f3d-a208-224f4eeb942a").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }if ((window.Jupyter !== undefined) && Jupyter.notebook.kernel) {
#       comm_manager = Jupyter.notebook.kernel.comm_manager
#       comm_manager.register_target("e8515a72-213b-4a6d-a2bd-ef3c569f3fbe", function () {});
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("9d5a2937-92fd-4f3d-a208-224f4eeb942a");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '9d5a2937-92fd-4f3d-a208-224f4eeb942a' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"88a23274-06f3-4f2b-a1c3-b329c03e3502":{"roots":{"references":[{"attributes":{"formatter":{"id":"fe6178e0-cd00-4b7d-976a-580f175a0d67","type":"BasicTickFormatter"},"plot":{"id":"7221971e-335e-412c-9a6b-f271b23aeb1d","subtype":"Figure","type":"Plot"},"ticker":{"id":"072adc86-bb7b-4f27-826a-9125aba4e1d4","type":"BasicTicker"}},"id":"15dff864-e4a9-4f88-b046-d821583069c6","type":"LinearAxis"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":20},"x":{"field":"x"},"y":{"field":"y"}},"id":"6c1ab317-c82e-4606-8681-92553a62eaf9","type":"Circle"},{"attributes":{"formatter":{"id":"5932e670-78c8-4b51-984b-06850380dc58","type":"BasicTickFormatter"},"plot":{"id":"946ed5bd-d978-4ad9-92a8-dc0439f34dc5","subtype":"Figure","type":"Plot"},"ticker":{"id":"ec0847b8-b85f-4400-a110-d116acff7eb5","type":"BasicTicker"}},"id":"fc3fedaf-5742-4556-979b-605778b87066","type":"LinearAxis"},{"attributes":{"plot":{"id":"946ed5bd-d978-4ad9-92a8-dc0439f34dc5","subtype":"Figure","type":"Plot"}},"id":"8be47fcc-c2b7-44cf-b972-508bfb8a8e51","type":"HelpTool"},{"attributes":{"formatter":{"id":"79e0d948-a37e-4653-b891-8e368d997a3f","type":"BasicTickFormatter"},"plot":{"id":"7221971e-335e-412c-9a6b-f271b23aeb1d","subtype":"Figure","type":"Plot"},"ticker":{"id":"3c11c671-c86c-4b8a-b5b2-367706930f18","type":"BasicTicker"}},"id":"7f75885a-de65-4597-ab10-92db3fd2aa77","type":"LinearAxis"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"da963308-7385-435a-b9f0-def18571fcdf","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"7221971e-335e-412c-9a6b-f271b23aeb1d","subtype":"Figure","type":"Plot"}},"id":"a28a182a-1d66-446a-92c0-4f3dd06dba8c","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"7221971e-335e-412c-9a6b-f271b23aeb1d","subtype":"Figure","type":"Plot"},"ticker":{"id":"3c11c671-c86c-4b8a-b5b2-367706930f18","type":"BasicTicker"}},"id":"855aa82b-a1e3-426a-acb1-9e75eef039b4","type":"Grid"},{"attributes":{"plot":{"id":"7221971e-335e-412c-9a6b-f271b23aeb1d","subtype":"Figure","type":"Plot"}},"id":"da029673-783d-43b8-aab9-275fb1b76aab","type":"ResetTool"},{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":20},"x":{"field":"x"},"y":{"field":"y"}},"id":"af80c528-931a-4ba3-9596-6a6e7cebe1b1","type":"Circle"},{"attributes":{"dimension":1,"plot":{"id":"7221971e-335e-412c-9a6b-f271b23aeb1d","subtype":"Figure","type":"Plot"},"ticker":{"id":"072adc86-bb7b-4f27-826a-9125aba4e1d4","type":"BasicTicker"}},"id":"001eb84c-1747-41e6-9c00-c9018a912966","type":"Grid"},{"attributes":{"formatter":{"id":"ae399914-7774-4773-9eb3-faec6828886f","type":"BasicTickFormatter"},"plot":{"id":"946ed5bd-d978-4ad9-92a8-dc0439f34dc5","subtype":"Figure","type":"Plot"},"ticker":{"id":"938aa71b-84e6-4051-ae07-5f88a3c030c5","type":"BasicTicker"}},"id":"07af1abe-26b0-4d79-87f1-802609a961dd","type":"LinearAxis"},{"attributes":{},"id":"ce419810-d70a-416b-aeb3-7f20e2ac39e1","type":"ToolEvents"},{"attributes":{"plot":{"id":"946ed5bd-d978-4ad9-92a8-dc0439f34dc5","subtype":"Figure","type":"Plot"}},"id":"30ec9049-6c1c-4aec-a5f9-f963d512c269","type":"ResetTool"},{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":20},"x":{"field":"x"},"y":{"field":"y"}},"id":"deb3c3bb-1588-476a-ab9e-8978ceba4747","type":"Circle"},{"attributes":{"plot":{"id":"946ed5bd-d978-4ad9-92a8-dc0439f34dc5","subtype":"Figure","type":"Plot"}},"id":"7715dca3-1dac-4fc7-97ec-ad84849bcd2b","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"946ed5bd-d978-4ad9-92a8-dc0439f34dc5","subtype":"Figure","type":"Pl ...

# %%
# the comms handle repr show what cell it can be used to update
t
# Out:
# <p><code>&lt;Bokeh Notebook handle for <strong>In[4]</strong>&gt;</code></p>

# %%
# this will update the left plot circle color with an explicit handle
r1.glyph.fill_color = "white"
push_notebook(handle=t)

# %%
# and this will update the right plot circle color because it was in the last shown cell
r2.glyph.fill_color = "pink"
push_notebook()

# %%
p3 = figure(**opts)
r3 = p3.circle([1,2,3], [4,5,6], size=20)

# get a handle to update the shown cell with
t2 = show(p3, notebook_handle=True)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="ccec74c5-b3fe-4cfe-b143-10b1d1838931"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#ccec74c5-b3fe-4cfe-b143-10b1d1838931").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }if ((window.Jupyter !== undefined) && Jupyter.notebook.kernel) {
#       comm_manager = Jupyter.notebook.kernel.comm_manager
#       comm_manager.register_target("69918167-7a11-46f9-8b92-8d5072009b7f", function () {});
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("ccec74c5-b3fe-4cfe-b143-10b1d1838931");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'ccec74c5-b3fe-4cfe-b143-10b1d1838931' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"dc0e7d9c-609d-408e-ab68-6b213243a0fe":{"roots":{"references":[{"attributes":{"plot":null,"text":null},"id":"47f43997-9169-4494-acc3-74f4bf5ba548","type":"Title"},{"attributes":{"plot":{"id":"efdee3e8-9f76-49eb-a25d-23126c3082f8","subtype":"Figure","type":"Plot"}},"id":"6800b409-38ec-4a31-ad2b-0876b6e1188b","type":"HelpTool"},{"attributes":{"callback":null},"id":"0ce878cf-257a-45b2-8311-acfb2903b544","type":"DataRange1d"},{"attributes":{"plot":{"id":"efdee3e8-9f76-49eb-a25d-23126c3082f8","subtype":"Figure","type":"Plot"}},"id":"96c3eb67-85fa-462e-ae61-2c1e0ac2b11b","type":"WheelZoomTool"},{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":20},"x":{"field":"x"},"y":{"field":"y"}},"id":"6c46eca0-546f-4f3d-9649-5e966d2fa1cc","type":"Circle"},{"attributes":{"below":[{"id":"011ecf49-14ba-4fc3-b88a-22a78f41051b","type":"LinearAxis"}],"left":[{"id":"1c66bb81-09bf-498d-9193-eb86ffef423c","type":"LinearAxis"}],"min_border":0,"plot_height":250,"plot_width":250,"renderers":[{"id":"011ecf49-14ba-4fc3-b88a-22a78f41051b","type":"LinearAxis"},{"id":"a1b07658-d12e-4ad6-a9ac-7b498f2de8f2","type":"Grid"},{"id":"1c66bb81-09bf-498d-9193-eb86ffef423c","type":"LinearAxis"},{"id":"29c21ea7-bcdd-4f60-9901-015b9bec157d","type":"Grid"},{"id":"07fc4a6e-d0b6-44ff-b10c-088bbb2f4cc8","type":"BoxAnnotation"},{"id":"af2b9174-c287-477f-9eda-5d08c96bf87e","type":"GlyphRenderer"}],"title":{"id":"47f43997-9169-4494-acc3-74f4bf5ba548","type":"Title"},"tool_events":{"id":"38410614-1578-4da3-bc23-c2413fcaf757","type":"ToolEvents"},"toolbar":{"id":"c8e571b2-9d8d-4988-bc56-874da5467706","type":"Toolbar"},"x_range":{"id":"0ce878cf-257a-45b2-8311-acfb2903b544","type":"DataRange1d"},"y_range":{"id":"753c16ef-562d-406c-a7c5-99f2b4c25ba4","type":"DataRange1d"}},"id":"efdee3e8-9f76-49eb-a25d-23126c3082f8","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"44f88c05-1a97-4194-aeee-62df97932f53","type":"BasicTicker"},{"attributes":{},"id":"38410614-1578-4da3-bc23-c2413fcaf757","type":"ToolEvents"},{"attributes":{"dimension":1,"plot":{"id":"efdee3e8-9f76-49eb-a25d-23126c3082f8","subtype":"Figure","type":"Plot"},"ticker":{"id":"44f88c05-1a97-4194-aeee-62df97932f53","type":"BasicTicker"}},"id":"29c21ea7-bcdd-4f60-9901-015b9bec157d","type":"Grid"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"07fc4a6e-d0b6-44ff-b10c-088bbb2f4cc8","type":"BoxAnnotation"},{"attributes":{},"id":"9e2c79c9-8632-480d-a5f3-288714911191","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"efdee3e8-9f76-49eb-a25d-23126c3082f8","subtype":"Figure","type":"Plot"}},"id":"df14ac53-c413-47b4-8c77-e814d9c873a0","type":"ResetTool"},{"attributes":{"overlay":{"id":"07fc4a6e-d0b6-44ff-b10c-088bbb2f4cc8","type":"BoxAnnotation"},"plot":{"id":"efdee3e8-9f76-49eb-a25d-23126c3082f8","subtype":"Figure","type":"Plot"}},"id":"ef155457-5eee-4fca-b826-fbce29e30130","type":"BoxZoomTool"},{"attributes":{"formatter":{"id":"a804497b-de2e-4971-8fa0-b5a50dbcc604","type":"BasicTickFormatter"},"plot":{"id":"efdee3e8-9f76-49eb-a25d-23126c3082f8","subtype":"Figure","type":"Plot"},"ticker":{"id":"44f88c05-1a97-4194-aeee-62df97932f53","type":"BasicTicker"}},"id":"1c66bb81-09bf-498d-9193-eb86ffef423c","type":"LinearAxis"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[1,2,3],"y":[4,5,6]}},"id":"1b6b2531-cc66-4ba5-979a-5da499b43130","type":"ColumnDataSource"},{"attributes":{},"id":"a804497b-de2e-4971-8fa0-b5a50dbcc604","type":"BasicTickFormatter"},{"attributes":{},"id":"d972df27-a4eb-4def-9abf-43306f8b1878","type":"BasicTicker"},{"attributes":{"plot":{"id":"efdee3e8-9f76-49eb-a25d-23126c3082f8","subtype":"Figure","type":"Plot"}},"id":"f41933d ...

# %%
# show which cell t2 handles
t2
# Out:
# <p><code>&lt;Bokeh Notebook handle for <strong>In[8]</strong>&gt;</code></p>

# %%
# this updates the immediately previous cell with an explicit handle
r3.glyph.fill_color = "orange"
push_notebook(handle=t2)

# %%
# this updates the left plot at the top with an explicit handle
r1.glyph.fill_color = "orange"
push_notebook(handle=t)

# %%
# get a handle to update the shown cell with
t3 = show(p2, notebook_handle=True)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="50b6aabd-25ea-498c-85de-22bbb443b2dd"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#50b6aabd-25ea-498c-85de-22bbb443b2dd").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }if ((window.Jupyter !== undefined) && Jupyter.notebook.kernel) {
#       comm_manager = Jupyter.notebook.kernel.comm_manager
#       comm_manager.register_target("b7371fb2-0a1c-4439-b8b1-94b7dfea1e68", function () {});
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("50b6aabd-25ea-498c-85de-22bbb443b2dd");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '50b6aabd-25ea-498c-85de-22bbb443b2dd' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"acf6ab7b-0d84-438b-83b2-5440a207ab35":{"roots":{"references":[{"attributes":{"formatter":{"id":"fe6178e0-cd00-4b7d-976a-580f175a0d67","type":"BasicTickFormatter"},"plot":{"id":"7221971e-335e-412c-9a6b-f271b23aeb1d","subtype":"Figure","type":"Plot"},"ticker":{"id":"072adc86-bb7b-4f27-826a-9125aba4e1d4","type":"BasicTicker"}},"id":"15dff864-e4a9-4f88-b046-d821583069c6","type":"LinearAxis"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":20},"x":{"field":"x"},"y":{"field":"y"}},"id":"6c1ab317-c82e-4606-8681-92553a62eaf9","type":"Circle"},{"attributes":{},"id":"fe6178e0-cd00-4b7d-976a-580f175a0d67","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"7221971e-335e-412c-9a6b-f271b23aeb1d","subtype":"Figure","type":"Plot"}},"id":"da029673-783d-43b8-aab9-275fb1b76aab","type":"ResetTool"},{"attributes":{"formatter":{"id":"79e0d948-a37e-4653-b891-8e368d997a3f","type":"BasicTickFormatter"},"plot":{"id":"7221971e-335e-412c-9a6b-f271b23aeb1d","subtype":"Figure","type":"Plot"},"ticker":{"id":"3c11c671-c86c-4b8a-b5b2-367706930f18","type":"BasicTicker"}},"id":"7f75885a-de65-4597-ab10-92db3fd2aa77","type":"LinearAxis"},{"attributes":{},"id":"79e0d948-a37e-4653-b891-8e368d997a3f","type":"BasicTickFormatter"},{"attributes":{},"id":"072adc86-bb7b-4f27-826a-9125aba4e1d4","type":"BasicTicker"},{"attributes":{"plot":{"id":"7221971e-335e-412c-9a6b-f271b23aeb1d","subtype":"Figure","type":"Plot"},"ticker":{"id":"3c11c671-c86c-4b8a-b5b2-367706930f18","type":"BasicTicker"}},"id":"855aa82b-a1e3-426a-acb1-9e75eef039b4","type":"Grid"},{"attributes":{"data_source":{"id":"b0d5020c-9b74-4e4a-b8a7-804d3d948fc5","type":"ColumnDataSource"},"glyph":{"id":"af80c528-931a-4ba3-9596-6a6e7cebe1b1","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"6c1ab317-c82e-4606-8681-92553a62eaf9","type":"Circle"},"selection_glyph":null},"id":"f4581e43-f7ee-43f7-a0a8-76a03bbf5ae4","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"7221971e-335e-412c-9a6b-f271b23aeb1d","subtype":"Figure","type":"Plot"}},"id":"cadaf18e-70d9-4eeb-8a85-b58fa7b6f761","type":"PanTool"},{"attributes":{},"id":"662af00c-dad6-4384-9b08-e9e2527ad662","type":"ToolEvents"},{"attributes":{"callback":null},"id":"9784d748-8b3f-4a09-8172-6fd8f691cb7f","type":"DataRange1d"},{"attributes":{"fill_color":{"value":"pink"},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":20},"x":{"field":"x"},"y":{"field":"y"}},"id":"af80c528-931a-4ba3-9596-6a6e7cebe1b1","type":"Circle"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"da963308-7385-435a-b9f0-def18571fcdf","type":"BoxAnnotation"},{"attributes":{"callback":null},"id":"b936ee29-fcc7-42f3-9b83-7abccdd7cf73","type":"DataRange1d"},{"attributes":{"plot":{"id":"7221971e-335e-412c-9a6b-f271b23aeb1d","subtype":"Figure","type":"Plot"}},"id":"a28a182a-1d66-446a-92c0-4f3dd06dba8c","type":"WheelZoomTool"},{"attributes":{"dimension":1,"plot":{"id":"7221971e-335e-412c-9a6b-f271b23aeb1d","subtype":"Figure","type":"Plot"},"ticker":{"id":"072adc86-bb7b-4f27-826a-9125aba4e1d4","type":"BasicTicker"}},"id":"001eb84c-1747-41e6-9c00-c9018a912966","type":"Grid"},{"attributes":{"below":[{"id":"7f75885a-de65-4597-ab10-92db3fd2aa77","type":"LinearAxis"}],"left":[{"id":"15dff864-e4a9-4f88-b046-d821583069c6","type":"LinearAxis"}],"min_border":0,"plot_height":250,"plot_width":250,"renderers":[{"id":"7f75885a-de65-4597-ab10-92db3fd2aa77","type":"LinearAxis"},{"id":"855aa82b-a1e3-426a-acb1-9e75eef039b4","type":"Grid"},{"id":"15dff864-e4a9-4f88-b046-d821583069c6","type":"LinearAxis"},{"id":"001eb84c-1747-41e6-9c00-c9018a912966","type":"Grid"},{"id" ...

# %%
# this will update the immediately previous plot circle color because it was in the last shown cell
r2.glyph.fill_color = "red"
push_notebook()

# %%
# this will update the immediately previous plot circle color with an explicit handle
r2.glyph.fill_color = "blue"
push_notebook(handle=t3)
